# %%
# !pip install openai
from openai import OpenAI
from google.colab import userdata

open_ai_key = userdata.get('openai_tech16_proj_key')
client = OpenAI(api_key=open_ai_key)

# %%
# !pip install llama-index --upgrade

# %%
# !pip install pypdf

# %%
# !wget https://www.goldmansachs.com/insights/goldman-sachs-research/2024-us-equity-outlook-all-you-had-to-do-was-stay
# Out:
# --2024-08-30 00:30:31--  https://www.goldmansachs.com/insights/goldman-sachs-research/2024-us-equity-outlook-all-you-had-to-do-was-stay
# Resolving www.goldmansachs.com (www.goldmansachs.com)... 23.204.24.145
# Connecting to www.goldmansachs.com (www.goldmansachs.com)|23.204.24.145|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘2024-us-equity-outlook-all-you-had-to-do-was-stay.1’
#
# 2024-us-equity-outl     [ <=>                ] 431.88K  --.-KB/s    in 0.04s
#
# 2024-08-30 00:30:31 (12.0 MB/s) - ‘2024-us-equity-outlook-all-you-had-to-do-was-stay.1’ saved [442240]

# %%
import os
os.environ["openai_tech16_proj_key"] = open_ai_key

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# %%
# !ls
# Out:
# 2024-us-equity-outlook-all-you-had-to-do-was-stay    sample_data
# 2024-us-equity-outlook-all-you-had-to-do-was-stay.1

# %%
documents = SimpleDirectoryReader('./').load_data('2024-us-equity-outlook-all-you-had-to-do-was-stay.pdf')
# Out:
# Loading files: 100%|██████████| 2/2 [00:00<00:00,  4.34file/s]

# %%
documents[0]
# Out:
# Document(id_='224b0104-a9a3-4fae-84f8-e2874ffdb970', embedding=None, metadata={'file_path': '/content/2024-us-equity-outlook-all-you-had-to-do-was-stay', 'file_name': '2024-us-equity-outlook-all-you-had-to-do-was-stay', 'file_size': 442238, 'creation_date': '2024-08-30', 'last_modified_date': '2024-08-29'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><title>2024 US Equity Outlook: “All You Had To Do Was Stay” | Goldman Sachs</title><link rel="icon" type="image/svg+xml" href="https://cdn.gs.com/images/goldman-sachs/v1/gs-favicon.svg"/><link rel="alternate icon" href="https://cdn.gs.com/images/goldman-sachs/v1/gs-favicon.ico"/><link rel="mask-icon" h
# ...

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What is the outlook for the US stockmarket? Be concise")
print(response)
# Out:
# The outlook for the US stock market is positive, with Goldman Sachs Research forecasting the S&P 500 index to end 2024 at 4700, representing a 5% price gain and a total return of 6% including dividends.

# %%
chat_engine = index.as_chat_engine(chat_mode="openai", verbose=True)

# %%
response = chat_engine.chat("What is the outlook for the US stockmarket? Be concise")
print(response)
# Out:
# Added user message to memory: What is the outlook for the US stockmarket? Be concise
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input":"Outlook for the US stock market"}
# Got output: Goldman Sachs Research forecasts that the S&P 500 index will end 2024 at 4700, with a 12-month price gain of 5% and a total return of 6% including dividends. The baseline assumption is that the US economy will continue to expand at a modest pace without a recession, earnings will rise by 5%, and the equity market valuation will be around 18x P/E. The forecast suggests a return slightly below the typical 8% seen during presidential election years.
# ...
#
# ...

# %%
response = chat_engine.chat("What question did I ask you?")
print(response)
# Out:
# Added user message to memory: What question did I ask you?
# You asked about the outlook for the US stock market.

# %%
#load specific folder from google drive into colab
from google.colab import drive
drive.mount('/content/drive') # Mount to the existing 'drive' directory
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ZStanfordClasses/2024/LLM/TECH-16-Large-Language-Models-for-Business-with-Python-2024-Aug-30_01-25-14-798/Transcripts
# Out:
# /content/drive/MyDrive/ZStanfordClasses/2024/LLM/TECH-16-Large-Language-Models-for-Business-with-Python-2024-Aug-30_01-25-14-798/Transcripts

# %%
#list files from drive
# !ls
# Out:
# Class1_07182024.gdoc

# %%
# !pip install PyDrive

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
#!pip install gdown
# Download the Google Doc as a .txt file (replace with your file ID)
#!gdown '1n3z4T16m_Ej8KBWBcRA73V30t6IOMTudQnsxfwZwd0U' -O Class1_07182024.txt

#print content of the txt file
print(open('Class1_07182024.txt').read())

#read Class1_07182024.gdoc into SimpleDirectoryReader
# id = 1n3z4T16m_Ej8KBWBcRA73V30t6IOMTudQnsxfwZwd0U
documents = SimpleDirectoryReader('./').load_data(['Class1_07182024.txt'])

# %%
# Create a VectorStoreIndex object from the documents. This will involve processing the documents
# and creating a vector representation for each of them, suitable for semantic searching.
index = VectorStoreIndex.from_documents(documents)

# %%
# Convert the VectorStoreIndex object into a query engine. This query engine can be used to
# perform semantic searches on the index, matching natural language queries to the most relevant
# documents in the index.
query_engine = index.as_query_engine()

# %%
# Use the query engine to search for documents that are relevant to the query
# from the indexed documents based on the semantic understanding of the query.
response = query_engine.query("What was the duration of the class.")
print(response)
# Out:
# The duration of the class was not explicitly mentioned in the provided context.
